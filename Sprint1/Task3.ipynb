// %% [markdown]
// <h1 style="color:DodgerBlue">Индивидальный проект</h1>

// %% [markdown]
// <h2 style="color:DodgerBlue">Название проекта:</h2>
//
// ----
//
// ### Вариант задания №11

// %% [markdown]
// <h2 style="color:DodgerBlue">Описание проекта:</h2>
//
// ----
//
// Создать базовый класс Customer в C#, который будет представлять информацию о
// клиентах или покупателях. На основе этого класса разработать 2-3 производных
// класса, демонстрирующих принципы наследования и полиморфизма. В каждом из
// классов должны быть реализованы новые атрибуты и методы, а также
// переопределены некоторые методы базового класса для демонстрации
// полиморфизма.
//
// Требования к базовому классу Customer:
//
// • Атрибуты: Идентификатор клиента (CustomerId), Имя (Name), Электронная
//     почта (Email).
//
// • Методы:
//
//     o GetFullName(): метод для получения полного имени клиента.
//
//     o UpdateEmail(string newEmail): метод для обновления электронной
//         почты клиента.
//
//     o ViewProfile(): метод для просмотра профиля клиента.
//
// Требования к производным классам:
//
//     1. VIPКлиент (VipCustomer): Должен содержать дополнительные атрибуты,
//     такие как Баланс лояльности (LoyaltyPoints). Метод ViewProfile() должен быть
//     переопределен для отображения дополнительной информации о VIPклиенте.
//
//     2. ОбычныйКлиент (RegularCustomer): Должен содержать дополнительные
//     атрибуты, такие как Дата регистрации (RegistrationDate).
//     Метод UpdateEmail() должен быть переопределен для добавления
//     информации о дате последнего обновления электронной почты.
//
//     3. ГрупповойКлиент (GroupCustomer) (если требуется третий класс): Должен
//     содержать дополнительные атрибуты, такие как Название группы
//     (GroupName). Метод GetFullName() должен быть переопределен для
//     отображения названия группы вместо имени клиента.
//
// #### Дополнительное задание
// Добавьте к сущестующим классам конструктора классов с использованием гетторов и сетторов и реализуйте взаимодействие объектов между собой

// %% [markdown]
// <h2 style="color:DodgerBlue">Реализация:</h2>
//
// ----

// %%
using System;

class Customer
{
    private int customerId;
    private string name;
    private string email;

    public int CustomerId
    {
        get { return customerId; }
        set { customerId = value; }
    }

    public string Name
    {
        get { return name; }
        set { name = value; }
    }

    public string Email
    {
        get { return email; }
        set { email = value; }
    }

    public Customer(int id, string name, string email)
    {
        this.CustomerId = id;
        this.Name = name;
        this.Email = email;
    }

    public virtual string GetFullName()
    {
        return Name;
    }

    public virtual void UpdateEmail(string newEmail)
    {
        Email = newEmail;
        Console.WriteLine($"Email обновлён на: {newEmail}");
    }

    public virtual void ViewProfile()
    {
        Console.WriteLine($"ID клиента: {CustomerId}, Имя: {GetFullName()}, Электронная почта: {Email}");
    }
}

class VipCustomer : Customer
{
    private int loyaltyPoints;

    public int LoyaltyPoints
    {
        get { return loyaltyPoints; }
        set { loyaltyPoints = value; }
    }
    
    public VipCustomer(int id, string name, string email, int loyaltyPoints) : base(id, name, email)
    {
        this.LoyaltyPoints = loyaltyPoints;
    }

    public override void ViewProfile()
    {
        base.ViewProfile();
        Console.WriteLine($"Баланс лояльности: {LoyaltyPoints}");
    }
}

class RegularCustomer : Customer
{
    private string registrationDate;

    public string RegistrationDate
    {
        get { return registrationDate; }
        set { registrationDate = value; }
    }
    
    public RegularCustomer(int id, string name, string email, string registrationDate) : base(id, name, email)
    {
        this.RegistrationDate = registrationDate;
    }

    public override void UpdateEmail(string newEmail)
    {
        base.UpdateEmail(newEmail);
        Console.WriteLine($"Дата последнего обновления электронной почты: {DateTime.Now}");
    }
}

class GroupCustomer : Customer
{
    private string groupName;
    private List<RegularCustomer> customers = new List<RegularCustomer>();

    public string GroupName
    {
        get { return groupName; }
        set { groupName = value; }
    }

    public GroupCustomer(int id, string groupName, string email) : base(id, groupName, email)
    {
        this.GroupName = groupName;
    }

    public void Add(RegularCustomer customer)
    {
        customers.Add(customer);
    }


    public override string GetFullName()
    {
        return GroupName; 
    }

    public override void ViewProfile()
    {
        Console.WriteLine($"ID группы клиента: {CustomerId}, Название группы: {GetFullName()}, Электронная почта: {Email}");
        Console.WriteLine("Клиенты в группе:");
        foreach (var customer in customers)
        {
            customer.ViewProfile();
        }
    }
}

VipCustomer vipCustomer = new VipCustomer(1, "Петр Петров", "peter@example.com", 150);
Console.WriteLine("Профиль VIP клиента:");
vipCustomer.ViewProfile();

RegularCustomer regularCustomer1 = new RegularCustomer(2, "Сергей Сергеев", "sergey@example.com", DateTime.Now.ToString("dd/MM/yyyy"));
Console.WriteLine("\nПрофиль обычного клиента:");
regularCustomer1.ViewProfile();
regularCustomer1.UpdateEmail("sergey_new@example.com");

RegularCustomer regularCustomer2 = new RegularCustomer(3, "Анна Анновна", "anna@example.com", DateTime.Now.ToString("dd/MM/yyyy"));
Console.WriteLine("\nПрофиль обычного клиента:");
regularCustomer2.ViewProfile();
regularCustomer2.UpdateEmail("anna_new@example.com");

RegularCustomer regularCustomer3 = new RegularCustomer(4, "Михаил Михаилов", "michael@example.com", DateTime.Now.ToString("dd/MM/yyyy"));
Console.WriteLine("\nПрофиль обычного клиента:");
regularCustomer3.ViewProfile();
regularCustomer3.UpdateEmail("michael_new@example.com");

GroupCustomer groupCustomer = new GroupCustomer(5, "Группа A", "group_a@example.com");

groupCustomer.Add(regularCustomer1);
groupCustomer.Add(regularCustomer2);
groupCustomer.Add(regularCustomer3);

Console.WriteLine("\nПрофиль группового клиента:");
groupCustomer.ViewProfile();

static void InteractCustomers(Customer customer1, Customer customer2)
{
    
    Console.WriteLine($"Клиент {customer1.GetFullName()} отправляет привет клиенту {customer2.GetFullName()}.");
    Console.WriteLine($"Клиент {customer2.GetFullName()} отвечает: Здравствуй, {customer1.GetFullName()}!");
}
Console.WriteLine("\nВзаимодействие между клиентами:");
InteractCustomers(vipCustomer, regularCustomer1);
// Out:
// Профиль VIP клиента:
// ID клиента: 1, Имя: Петр Петров, Электронная почта: peter@example.com
// Баланс лояльности: 150
//
// Профиль обычного клиента:
// ID клиента: 2, Имя: Сергей Сергеев, Электронная почта: sergey@example.com
// Email обновлён на: sergey_new@example.com
// Дата последнего обновления электронной почты: 9/23/2024 1:39:34 PM
//
// Профиль обычного клиента:
// ID клиента: 3, Имя: Анна Анновна, Электронная почта: anna@example.com
// Email обновлён на: anna_new@example.com
// Дата последнего обновления электронной почты: 9/23/2024 1:39:34 PM
//
// Профиль обычного клиента:
// ID клиента: 4, Имя: Михаил Михаилов, Электронная почта: michael@example.com
// Email обновлён на: michael_new@example.com
// Дата последнего обновления электронной почты: 9/23/2024 1:39:34 PM
//
// Профиль группового клиента:
// ID группы клиента: 5, Название группы: Группа A, Электронная почта: group_a@example.com
// Клиенты в группе:
// ID клиента: 2, Имя: Сергей Сергеев, Электронная почта: sergey_new@example.com
// ID клиента: 3, Имя: Анна Анновна, Электронная почта: anna_new@example.com
// ID клиента: 4, Имя: Михаил Михаилов, Электронная почта: michael_new@example.com
//
// Взаимодействие между клиентами:
// Клиент Петр Петров отправляет привет клиенту Сергей Сергеев.
// Клиент Сергей Сергеев отвечает: Здравствуй, Петр Петров!
